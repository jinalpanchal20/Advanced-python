# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
li=[1,2,-3,6.2,'data values']

# %%
li
# Out:
# [1, 2, -3, 6.2, 'data values']

# %%
seri1=pd.Series(li)
print(seri1)
# Out:
# 0              1
# 1              2
# 2             -3
# 3            6.2
# 4    data values
# dtype: object

# %%
type(seri1)
# Out:
# pandas.core.series.Series

# %%
seri2=pd.Series([1,2,3,4])

# %%
seri2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s4=pd.Series([1,2,3,4])
s4
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s4[0]
# Out:
# 1

# %%
s4[2]
# Out:
# 3

# %%
s4[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(s4)
# Out:
# 4

# %%
min(s4)
# Out:
# 1

# %% [markdown]
# how to create python pandas **DataFrame**

# %%
lst=['a','b','c']
lst
# Out:
# ['a', 'b', 'c']

# %%
df1=pd.DataFrame(lst)
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls1=[[1,2,3],[4,6,7],[0,4,9]]
df2=pd.DataFrame(ls1)
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  6  7
# 2  0  4  9

# %%
di={'id':[1,2,3,4],'rn':[7,9,0,4]}
pd.DataFrame(di)
# Out:
#    id  rn
# 0   1   7
# 1   2   9
# 2   3   0
# 3   4   4

# %%
df=pd.read_csv('Downloads/heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3    0.23
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3    0.23
# 1   0     3    0.37
# 2   0     3    0.24
# 3   1     3    0.28
# 4   3     2    0.21

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2    0.85
# 1021      1   1     3    0.40
# 1022      1   1     2    0.15
# 1023      2   0     2    0.82
# 1024      1   1     3    0.39

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# age         1025
# sex         1025
# cp          1025
# trestbps    1025
# chol        1025
# fbs         1025
# restecg     1025
# thalach     1025
# exang       1025
# oldpeak     1025
# slope       1025
# ca          1025
# thal        1025
# target      1025
# dtype: int64

# %%
df.dropna()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3    0.23
# ...

# %% [markdown]
# **replace()**

# %%
df.replace({'sex':0},'male')
# Out:
#       age   sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52     1   0       125   212    0        1      168      0      1.0
# 1      53     1   0       140   203    1        0      155      1      3.1
# 2      70     1   0       145   174    0        1      125      1      2.6
# 3      61     1   0       148   203    0        1      161      0      0.0
# 4      62  male   0       138   294    1        1      106      0      1.9
# ...   ...   ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59     1   1       140   221    0        1      164      1      0.0
# 1021   60     1   0       125   258    0        0      141      1      2.8
# 1022   47     1   0       110   275    0        0      118      1      1.0
# 1023   50  male   0       110   254    0        0      159      0      0.0
# 1024   54     1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3    0.23
# ...

# %%
#interpolate missing value fill kare

# %%
df.interpolate()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3    0.23
# ...

# %%
df.loc[0]
# Out:
# age          52.00
# sex           1.00
# cp            0.00
# trestbps    125.00
# chol        212.00
# fbs           0.00
# restecg       1.00
# thalach     168.00
# exang         0.00
# oldpeak       1.00
# slope         2.00
# ca            2.00
# thal          3.00
# target        0.23
# Name: 0, dtype: float64

# %%
df.loc[5]
# Out:
# age          58.00
# sex           0.00
# cp            0.00
# trestbps    100.00
# chol        248.00
# fbs           0.00
# restecg       0.00
# thalach     122.00
# exang         0.00
# oldpeak       1.00
# slope         1.00
# ca            0.00
# thal          2.00
# target        0.78
# Name: 5, dtype: float64
